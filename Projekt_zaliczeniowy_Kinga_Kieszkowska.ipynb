# %% [markdown]
# <a href="https://colab.research.google.com/github/kinga98/Programowanie-API-1-rok-mgr/blob/main/Projekt_zaliczeniowy_Kinga_Kieszkowska.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=df = pd.read_csv("/content/all_tweets_ids.csv")

# %%
df
# Out:
#       coordinates                      created_at  ... user_urls user_verified
# 0             NaN  Fri Sep 24 12:50:22 +0000 2021  ...       NaN         False
# 1             NaN  Fri Sep 24 13:18:46 +0000 2021  ...       NaN         False
# 2             NaN  Fri Sep 24 12:51:09 +0000 2021  ...       NaN         False
# 3             NaN  Fri Sep 24 13:14:46 +0000 2021  ...       NaN         False
# 4             NaN  Fri Sep 24 13:13:42 +0000 2021  ...       NaN         False
# ...           ...                             ...  ...       ...           ...
# 15904         NaN  Mon Sep 20 02:26:54 +0000 2021  ...       NaN         False
# 15905         NaN  Mon Sep 20 00:29:27 +0000 2021  ...       NaN         False
# 15906         NaN  Mon Sep 20 00:37:28 +0000 2021  ...       NaN         False
# 15907         NaN  Mon Sep 20 01:34:13 +0000 2021  ...       NaN         False
# 15908         NaN  Mon Sep 20 01:12:00 +0000 2021  ...       NaN         False
#
# ...

# %%
df_tvp = df.copy()

# %% [markdown]
# Część 1

# %% [markdown]
# Zadanie 1

# %%
df_tvp["created_at"] = [wiersz.replace("Mon", "Poniedziałek") for wiersz in df_tvp["created_at"]]
df_tvp["created_at"] = [wiersz.replace("Tue", "Wtorek") for wiersz in df_tvp["created_at"]]
df_tvp["created_at"] = [wiersz.replace("Wed", "Środa") for wiersz in df_tvp["created_at"]]
df_tvp["created_at"] = [wiersz.replace("Thu", "Czwartek") for wiersz in df_tvp["created_at"]]
df_tvp["created_at"] = [wiersz.replace("Fri", "Piątek") for wiersz in df_tvp["created_at"]]
df_tvp["created_at"] = [wiersz.replace("Sat", "Sobota") for wiersz in df_tvp["created_at"]]
df_tvp["created_at"] = [wiersz.replace("Sun", "Niedziela") for wiersz in df_tvp["created_at"]]

# %%
df_tvp
# Out:
#       coordinates  ... user_verified
# 0             NaN  ...         False
# 1             NaN  ...         False
# 2             NaN  ...         False
# 3             NaN  ...         False
# 4             NaN  ...         False
# ...           ...  ...           ...
# 15904         NaN  ...         False
# 15905         NaN  ...         False
# 15906         NaN  ...         False
# 15907         NaN  ...         False
# 15908         NaN  ...         False
#
# [15909 rows x 35 columns]

# %% [markdown]
# Zadanie 2

# %%
df_tvp["user_created_at"] = [wiersz.replace("Jan", "01") for wiersz in df_tvp["user_created_at"]]
df_tvp["user_created_at"] = [wiersz.replace("Feb", "02") for wiersz in df_tvp["user_created_at"]]
df_tvp["user_created_at"] = [wiersz.replace("Mar", "03") for wiersz in df_tvp["user_created_at"]]
df_tvp["user_created_at"] = [wiersz.replace("Apr", "04") for wiersz in df_tvp["user_created_at"]]
df_tvp["user_created_at"] = [wiersz.replace("May", "05") for wiersz in df_tvp["user_created_at"]]
df_tvp["user_created_at"] = [wiersz.replace("Jun", "06") for wiersz in df_tvp["user_created_at"]]
df_tvp["user_created_at"] = [wiersz.replace("Jul", "07") for wiersz in df_tvp["user_created_at"]]
df_tvp["user_created_at"] = [wiersz.replace("Aug", "08") for wiersz in df_tvp["user_created_at"]]
df_tvp["user_created_at"] = [wiersz.replace("Sep", "09") for wiersz in df_tvp["user_created_at"]]
df_tvp["user_created_at"] = [wiersz.replace("Oct", "10") for wiersz in df_tvp["user_created_at"]]
df_tvp["user_created_at"] = [wiersz.replace("Nov", "11") for wiersz in df_tvp["user_created_at"]]
df_tvp["user_created_at"] = [wiersz.replace("Dec", "12") for wiersz in df_tvp["user_created_at"]]

# %%
df_tvp
# Out:
#       coordinates  ... user_verified
# 0             NaN  ...         False
# 1             NaN  ...         False
# 2             NaN  ...         False
# 3             NaN  ...         False
# 4             NaN  ...         False
# ...           ...  ...           ...
# 15904         NaN  ...         False
# 15905         NaN  ...         False
# 15906         NaN  ...         False
# 15907         NaN  ...         False
# 15908         NaN  ...         False
#
# [15909 rows x 35 columns]

# %% [markdown]
# Zadanie 3

# %%
lista1 = df_tvp["tweet_url"]

# %%
df_dane = pd.DataFrame({"tweet_url" : lista1})

# %%
lista1
# Out:
# 0        https://twitter.com/lesbostambul/status/144138...
# 1        https://twitter.com/chrispie1234/status/144139...
# 2        https://twitter.com/Andrzej31263190/status/144...
# 3        https://twitter.com/RyszardKujawis1/status/144...
# 4        https://twitter.com/ad_dexteram/status/1441390...
#                                ...
# 15904    https://twitter.com/Andrzej31263190/status/143...
# 15905    https://twitter.com/a_matu_/status/14397485051...
# 15906    https://twitter.com/k_gumkowski/status/1439750...
# 15907    https://twitter.com/Mark19556/status/143976480...
# 15908    https://twitter.com/Egonis_79/status/143975921...
# Name: tweet_url, Length: 15909, dtype: object

# %% [markdown]
# Zadanie 4

# %%
url_lista = list(df_tvp["tweet_url"]) 
#print(url_lista)

# %%
tmp_df = df_tvp.dropna(subset=['urls']) 
linki = list(tmp_df["urls"])
#print(linki)

# %% [markdown]
# Zadanie 5

# %%
url_obrazki_lista = list(df_tvp["media"]) 
#print(url_obrazki_lista)

# %%
tmp_df = df_tvp.dropna(subset=['urls']) 
linki2 = list(tmp_df["urls"])
#print(linki2)

# %% [markdown]
# Zadanie 6

# %%
# !pip install spacy -U
# !python -m spacy download pl_core_news_lg
# Out:
# ...
#      |████████████████████████████████| 612.1 MB 10 kB/s
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pl_core_news_lg')

# %%
import spacy 
# !python -m spacy download pl_core_news_sm
# Out:
# ...
#      |████████████████████████████████| 58.6 MB 134 kB/s
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('pl_core_news_sm')

# %%
sp = spacy.load('pl_core_news_sm')

all_stopwords = sp.Defaults.stop_words

df['text_without_stopwords'] = df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (all_stopwords)]))

# %%
df[['text_without_stopwords','text']]
# Out:
#                                   text_without_stopwords                                               text
# 0      2/2 Potrafimy walczyć nikt, powtórzę NIKT stan...  2/2\nPotrafimy walczyć o swoje i nikt, powtórz...
# 1      Sorki,że przeoczyłam spotkanie ☺️ ! Nazisynu @...  Sorki,że przeoczyłam to spotkanie ☺️ !\nNazisy...
# 2      Niemcy🇩🇪 Stralsund. Kanclerz Merkel wygwizdana...  Niemcy🇩🇪 Stralsund. Kanclerz Merkel wygwizdana...
# 3      Pomyślcie tylko, rządzi PO kolumny emigrantów ...  Pomyślcie tylko, że rządzi PO i kolumny emigra...
# 4      Może rząd zacząć publikować gorsze wyniki ekon...  Może rząd powinien zacząć publikować gorsze wy...
# ...                                                  ...                                                ...
# 15904  Wrócił własnej woli, Niemcy Polski wysłali? #T...  Wrócił sam z własnej woli, czy go Niemcy do Po...
# 15905  Posełka @senyszyn_joanna : "Kościół popierał H...  Posełka @senyszyn_joanna :\n"Kościół popierał ...
# ...

# %% [markdown]
# Część 2

# %% [markdown]
# Zadanie 1

# %%
df_sorted_by_favourites = df.sort_values(by=["user_favourites_count"], ascending=False)
d = df_sorted_by_favourites.head(5)
d['text']
# Out:
# 15628    @TheRealAndreasB Dzień bez antypolskiego kłams...
# 5330     @aski_pu @antekszprycha92 @AzkaMarek @AnnaZale...
# 15277    PO i Niemcy boją się ujawnić dane dotyczące fi...
# 13330    Ponad 3 tygodnie temu nasi dziennikarze prosil...
# 14427    Takie ładne miasto 🤦‍♂️ Powodem manifestacji b...
# Name: text, dtype: object

# %% [markdown]
# Zadanie 2

# %%
df_sorted_by_retweet = df.sort_values(by=['retweet_count'], ascending=False)
d = df_sorted_by_retweet.head(5)
d['text']
# Out:
# 975     Kopalnie węgla brunatnego w okolicach Turowa\n...
# 1050    Kopalnie węgla brunatnego w okolicach Turowa\n...
# 1059    Kopalnie węgla brunatnego w okolicach Turowa\n...
# 1062    Kopalnie węgla brunatnego w okolicach Turowa\n...
# 1063    Kopalnie węgla brunatnego w okolicach Turowa\n...
# Name: text, dtype: object

# %% [markdown]
# Zadanie 3

# %%
df_not_possibly_sensitive = df.loc[df['possibly_sensitive'] == False]
df_not_possibly_sensitive
# Out:
#       coordinates  ...                             text_without_stopwords
# 8             NaN  ...  Kopalnie węgla brunatnego okolicach Turowa Nie...
# 13            NaN  ...  Kopalnie węgla brunatnego okolicach Turowa Nie...
# 15            NaN  ...  Niemcy włączają sporu Turów. "Dwóch jednego?" ...
# 17            NaN  ...  W Aldi dostępnych metod płatności zakupy. Wpro...
# 22            NaN  ...  https://t.co/jXf3PtXvUF Gdzie kamery, ekolodzy...
# ...           ...  ...                                                ...
# 15875         NaN  ...  Wrócił własnej woli, Niemcy Polski wysłali? #T...
# 15878         NaN  ...  Niemcy - 0 Polska - 1 👉 Wicenaczelny "GW" prze...
# 15894         NaN  ...  Wrócił własnej woli, Niemcy Polski wysłali? #T...
# 15899         NaN  ...  Niemcy swoimi okrętami ostatnio posłani wybrze...
# 15904         NaN  ...  Wrócił własnej woli, Niemcy Polski wysłali? #T...
#
# [3083 rows x 36 columns]

# %% [markdown]
# Zadanie 4

# %%
df_sorted_by_created_at = df.sort_values(by=['user_created_at'], ascending=False)
user_id = df_sorted_by_created_at.head(1)['user_id'].iloc[0]
df.loc[df['user_id'] == user_id]
# Out:
#      coordinates  ...                             text_without_stopwords
# 7752         NaN  ...  @AnnaZalewskaMEP Niemcy - mix energetyczny: wę...
#
# [1 rows x 36 columns]

# %% [markdown]
# Zadanie 5

# %%
df_sorted_by_created_at = df.sort_values(by = ['user_followers_count'], ascending=False)
user_id = df_sorted_by_created_at.head(1)['user_id'].iloc[0]
df.loc[df['user_id'] == user_id]
# Out:
#      coordinates  ...                             text_without_stopwords
# 8860         NaN  ...  Z danych sierpień wynika, ciągu miesięcy liczb...
# 9583         NaN  ...  [AKTUALIZACJA] Uzbrojony osobnik, wziął zakład...
# 9659         NaN  ...  Policja potwierdziła, autostrada została zamkn...
#
# [3 rows x 36 columns]

# %% [markdown]
# Zadanie 6

# %%
df_verified = df.loc[df['user_verified'] == True]
df_verified
# Out:
#       coordinates  ...                             text_without_stopwords
# 80            NaN  ...  #Sondaż: Dwa dni wyborów #Niemcy - #SPD wciąż ...
# 148           NaN  ...  .@LidiaGibadlo @Int_Wydarzenia prognozach doty...
# 239           NaN  ...  Migranci przewóz Polskę Niemiec płacą 1,5 tys....
# 309           NaN  ...  Niemiecka prasa: Migranci przewóz Polskę RFN p...
# 320           NaN  ...  #Niemcy: Wybory parlamentarne niedziele #wiesz...
# ...           ...  ...                                                ...
# 15413         NaN  ...  Mijają trzy tygodnie, odkąd portal @tvp_info p...
# 15624         NaN  ...  Ostatnia debata niemieckimi wyborami. Kandydat...
# 15689         NaN  ...  Mijają trzy tygodnie, odkąd portal @tvp_info p...
# 15702         NaN  ...  Wybory Niemczech. Zdaniem widzów ostatnią deba...
# 15798         NaN  ...  #Niemcy: Kandydat #SPD kanclerza, @OlafScholz,...
#
# [112 rows x 36 columns]

# %% [markdown]
# Zadanie 7

# %%
from spacy import displacy

# %%
import pandas as pd
import numpy as np
import spacy
import os
from tqdm import tqdm

# %%
import difflib

# %%
df_tvp = df.copy()

df_tvp['created_at_day'] = df_tvp['created_at'].str.split(" ").str[0]

print("Dzień tygodnia, w którym tweety były najczęściej publikowane:", df_tvp['created_at_day'].value_counts().idxmax())
# Out:
# Dzień tygodnia, w którym tweety były najczęściej publikowane: Thu

# %% [markdown]
# Część 3

# %% [markdown]
# Zadanie 1

# %%
def osoby(text):
  doc = sp(text)
  ents = doc.ents
  return ' '.join([ent.text for ent in ents if ent.label_ == "persName"])

df["persons"] = df["text"].apply(osoby)

# %% [markdown]
# Zadanie 2

# %%
def miejsca (text):
  doc = sp(text)
  ents = doc.ents
  return ' '.join([ent.text for ent in ents if ent.label_ == "placeName"])

df["places"] = df["text"].apply(miejsca)

# %% [markdown]
# Zadanie 3

# %%
def organizacje (text):
  doc = sp(text)
  ents = doc.ents
  return ' '.join([ent.text for ent in ents if ent.label_ == "orgName"])

df["organizations"] = df["text"].apply(organizacje)

# %% [markdown]
# Zadanie 4

# %%
import spacy

# %%
nlp_blank = spacy.blank("pl")
ruler = nlp_blank.add_pipe("entity_ruler")

pattern = "\S+"
patterns = [{"label": "HASHTAG", "pattern": [{"ORTH": "#"}, {"TEXT": {"REGEX": pattern}}]}]

ruler.add_patterns(patterns)

def hashtag(tekst):
  doc = nlp_blank(tekst)
  result = ""
  for ent in doc.ents:
    if ent.label_ == "HASHTAG":
      result += ent.text + " "
  return result

df_tvp["hashtags"] = df_tvp["text"].apply(hashtag)

df_tvp
# Out:
#       coordinates  ... created_at_day
# 0             NaN  ...            Fri
# 1             NaN  ...            Fri
# 2             NaN  ...            Fri
# 3             NaN  ...            Fri
# 4             NaN  ...            Fri
# ...           ...  ...            ...
# 15904         NaN  ...            Mon
# 15905         NaN  ...            Mon
# 15906         NaN  ...            Mon
# 15907         NaN  ...            Mon
# 15908         NaN  ...            Mon
#
# [15909 rows x 37 columns]

# %% [markdown]
# Część 4

# %%
import matplotlib.pyplot as plt

# %%
df_tvp = df.copy()

# %%
df_tvp
# Out:
#       coordinates  ...                                      organizations
# 0             NaN  ...                                               NIKT
# 1             NaN  ...
# 2             NaN  ...                                           Niemcy🇩🇪
# 3             NaN  ...                                                 PO
# 4             NaN  ...
# ...           ...  ...                                                ...
# 15904         NaN  ...
# 15905         NaN  ...  Kościół Niemieckim Obozie Śmierci "KL Dachau" ...
# 15906         NaN  ...  Kościół Niemieckim Obozie Śmierci "KL Dachau" ...
# 15907         NaN  ...  Kościół Niemieckim Obozie Śmierci "KL Dachau" ...
# 15908         NaN  ...                          zakażeń\n zakażeń\n\n2020
#
# [15909 rows x 39 columns]

# %%
days = ["Poniedziałek", "Wtorek", "Środa", "Czwartek", "Piątek", "Sobota", "Niedziela"]

df_tvp = df_tvp.groupby(['created_at_day']).size().reindex(days)

df_tvp.plot(x=df_tvp[0], y=df_tvp[1], kind="bar")
